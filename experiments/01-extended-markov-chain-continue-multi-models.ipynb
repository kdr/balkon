# %%
# https://www.music21.org/music21docs/about/referenceCorpus.html#referencecorpus
from tqdm import tqdm
from music21 import corpus, metadata, note, stream

def corpus_to_training_data(composer):
    paths = corpus.getComposer(composer)

    all_states = set()
    all_pitches = set()
    all_durations = set()
    training_data = []
    chord_occurence_count = 0
    note_count = 0
    for p in tqdm(paths):
        # Load the score
        s = corpus.parse(p)
        
        soprano_part = None
        for part in s.parts:
            if "Soprano" in (part.partName or ""):  # Check for 'Soprano' in the part name
                soprano_part = part
                break
        
        # Fallback if no explicit Soprano part is named
        if soprano_part is None:
            # Assume the first part is the Soprano if no explicit naming is found
            soprano_part = s.parts[0]
        
        # Extract notes and rests (pitch and duration)
        notes_sequence = []
        for element in soprano_part.flat.notesAndRests:  # Include notes and rests
            if element.isNote:
                notes_sequence.append((element.pitch.nameWithOctave, element.quarterLength))
            elif element.isChord:        
                # If there's a chord, take the highest note (melodic line usually uses the top note)
                #notes_sequence.append((element.highestNote.nameWithOctave, element.quarterLength))
    
                # Get the bass (lowest) note of the chord
                bass_note = element.bass()
                notes_sequence.append((bass_note.nameWithOctave, element.quarterLength))
    
                chord_occurence_count += 1
            elif element.isRest:
                notes_sequence.append(('Rest', element.quarterLength))
    
        notes = []
        for pitch, duration in notes_sequence:    
            all_pitches.add(pitch)
            all_durations.add(duration)
            s = (pitch, duration)
            if pitch == 'Rest':
                notes.append(note.Rest(quarterLength=s[1]))
                #ignore rests for now
                #pass
            else:
                notes.append(note.Note(s[0], quarterLength=s[1]))        
            all_states.add(s)    
        training_data.append(notes)
        note_count += len(notes)

    print(f'note_count: {note_count}\nskipped_chord_occurence_count: {chord_occurence_count}\ntraining_data_examples: {len(training_data)}\nall_states: {len(all_states)}, all_pitches: {len(all_pitches)}')        
    return training_data, list(all_states)

# %%
bach_data, bach_states = corpus_to_training_data('bach')
# Out:
# /Users/kdr/.pyenv/versions/3.12.8/envs/default/lib/python3.12/site-packages/music21/stream/base.py:3689: Music21DeprecationWarning: .flat is deprecated.  Call .flatten() instead       | 0/433 [00:00<?, ?it/s]
#   return self.iter().getElementsByClass(classFilterList)
# /Users/kdr/.pyenv/versions/3.12.8/envs/default/lib/python3.12/site-packages/music21/stream/base.py:3689: Music21DeprecationWarning: .flat is deprecated.  Call .flatten() instead06/433 [00:01<00:05, 56.99it/s]
#   return self.iter().getElementsByClass(classFilterList)
# /Users/kdr/.pyenv/versions/3.12.8/envs/default/lib/python3.12/site-packages/music21/stream/base.py:3689: Music21DeprecationWarning: .flat is deprecated.  Call .flatten() instead14/433 [00:01<00:05, 62.34it/s]
#   return self.iter().getElementsByClass(classFilterList)
# /Users/kdr/.pyenv/versions/3.12.8/envs/default/lib/python3.12/site-packages/music21/stream/base.py:3689: Music21DeprecationWarning: .flat is deprecated.  Call .flatten() instead39/433 [00:02<00:05, 57.93it/s]
#   return self.iter().getElementsByClass(classFilterList)
# In /Users/kdr/.pyenv/versions/3.12.8/envs/default/lib/python3.12/site-packages/matplotlib/mpl-data/stylelib/seaborn-v0_8-notebook.mplstyle: .flat is deprecated.  Call .flatten() instead00:02<00:04, 58.71it/s]
# In /Users/kdr/.pyenv/versions/3.12.8/envs/default/lib/python3.12/site-packages/matplotlib/mpl-data/stylelib/seaborn-v0_8-dark-palette.mplstyle: .flat is deprecated.  Call .flatten() instead
# In /Users/kdr/.pyenv/versions/3.12.8/envs/default/lib/python3.12/site-packages/matplotlib/mpl-data/stylelib/fast.mplstyle: .flat is deprecated.  Call .flatten() instead
# In /Users/kdr/.pyenv/versions/3.12.8/envs/default/lib/python3.12/site-packages/matplotlib/mpl-data/stylelib/grayscale.mplstyle: .flat is deprecated.  Call .flatten() instead
# In /Users/kdr/.pyenv/versions/3.12.8/envs/default/lib/python3.12/site-packages/matplotlib/mpl-data/stylelib/bmh.mplstyle: .flat is deprecated.  Call .flatten() instead
# /Users/kdr/.pyenv/versions/3.12.8/envs/default/lib/python3.12/site-packages/music21/stream/base.py:3689: Music21DeprecationWarning: .flat is deprecated.  Call .flatten() instead
#   return self.iter().getElementsByClass(classFilterList)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 433/433 [00:07<00:00, 57.27it/s]
# note_count: 23338
# skipped_chord_occurence_count: 1156
# training_data_examples: 433
# all_states: 212, all_pitches: 41

# %%
mozart_data, mozart_states = corpus_to_training_data('mozart')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:01<00:00,  9.59it/s]
# note_count: 7845
# skipped_chord_occurence_count: 64
# training_data_examples: 16
# all_states: 394, all_pitches: 56

# %%
#beethoven_data, beethoven_states = corpus_to_training_data('beethoven')

# %%
state_union = set()
state_union.update(bach_states)
state_union.update(mozart_states)
#state_union.update(beethoven_states)

len(state_union)
# Out:
# 445

# %%
# %%time
from simplemelodygen.extensions import MultiInstanceTrainableMarkovChainMelodyGenerator

bach_model = MultiInstanceTrainableMarkovChainMelodyGenerator(list(state_union))
bach_model.train(bach_data)
# Out:
# CPU times: user 35 ms, sys: 1.41 ms, total: 36.4 ms
# Wall time: 37 ms

# %%
# %%time
from simplemelodygen.extensions import MultiInstanceTrainableMarkovChainMelodyGenerator

mozart_model = MultiInstanceTrainableMarkovChainMelodyGenerator(list(state_union))
mozart_model.train(mozart_data)
# Out:
# CPU times: user 13.3 ms, sys: 1.11 ms, total: 14.4 ms
# Wall time: 13.8 ms

# %%
generated_melody, _ = bach_model.generate(20)

from music21 import metadata, note, stream

score = stream.Score()
score.metadata = metadata.Metadata(title="Markov Chain Melody - Random Bach")
part = stream.Part()
for n, d in generated_melody:
    if n == 'Rest':
        part.append(note.Rest(quarterLength=d))    
    else:
        part.append(note.Note(n, quarterLength=d))
score.append(part)

score.show('midi')
score.show()
# Out:
#         <div id="midiPlayerDiv256501"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv256501_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv256501");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv256501_play, 2000);
#         } else {
#             midiPlayerDiv256501_play();
#         }
#         </script>

# %%
generated_melody, _ = mozart_model.generate(20)

from music21 import metadata, note, stream

score = stream.Score()
score.metadata = metadata.Metadata(title="Markov Chain Melody - Random Mozart")
part = stream.Part()
for n, d in generated_melody:
    if n == 'Rest':
        part.append(note.Rest(quarterLength=d))    
    else:
        part.append(note.Note(n, quarterLength=d))
score.append(part)

score.show('midi')
score.show()
# Out:
#         <div id="midiPlayerDiv256797"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv256797_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv256797");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv256797_play, 2000);
#         } else {
#             midiPlayerDiv256797_play();
#         }
#         </script>

# %%
def show_score(melody, title='Markov Chain Melody'):
    score = stream.Score()
    score.metadata = metadata.Metadata(title=title)
    part = stream.Part()
    for n, d in melody:
        if n == 'Rest':
            part.append(note.Rest(quarterLength=d))    
        else:
            part.append(note.Note(n, quarterLength=d))
    score.append(part)
    
    score.show('midi')
    score.show()

# %%
# Extend twinkle twinkle

# %%
input_melody = [("C5", 1.0), ("C5", 1.0), ("G5", 1.0), ("G5", 1.0), ("A5", 1.0), ("A5", 1.0), ("G5", 2.0)]

show_score(input_melody, 'My Input: Twinkle Twinkle...')
# Out:
#         <div id="midiPlayerDiv257863"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv257863_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv257863");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv257863_play, 2000);
#         } else {
#             midiPlayerDiv257863_play();
#         }
#         </script>

# %%
full_melody, new_part = mozart_model.generate(20, previous_sequence=input_melody)

show_score(full_melody, 'Option: Mozart')
# Out:
#         <div id="midiPlayerDiv258074"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv258074_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv258074");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv258074_play, 2000);
#         } else {
#             midiPlayerDiv258074_play();
#         }
#         </script>

# %%
full_melody, new_part = bach_model.generate(20, previous_sequence=input_melody)

show_score(full_melody, 'Option: Bach')
# Out:
#         <div id="midiPlayerDiv258802"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv258802_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv258802");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv258802_play, 2000);
#         } else {
#             midiPlayerDiv258802_play();
#         }
#         </script>
